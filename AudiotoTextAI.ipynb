# %%
# !pip install gradio openai-whisper
# Out:
# Collecting gradio
#   Downloading gradio-6.18.0-py3-none-any.whl.metadata (17 kB)
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 5.9 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (4.13.0)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (6.1 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.137.1-py3-none-any.whl.metadata (26 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=1.2.0 (from gradio)
#   Downloading huggingface_hub-1.19.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (26.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<13.0,>=8.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (2.13.4)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (2023.3.post1)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=1.0.1 (from gradio)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from gradio) (0.49.0)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from gradio-client==2.5.0->gradio) (2023.10.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.11/site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Collecting click>=8.4.0 (from huggingface-hub<2.0,>=1.2.0->gradio)
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (3.13.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<4.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (15.0.0)
# Requirement already satisfied: more-itertools in /opt/anaconda3/lib/python3.11/site-packages (from openai-whisper) (10.1.0)
# Requirement already satisfied: numba in /opt/anaconda3/lib/python3.11/site-packages (from openai-whisper) (0.59.0)
# Requirement already satisfied: tiktoken in /opt/anaconda3/lib/python3.11/site-packages (from openai-whisper) (0.13.0)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.11/site-packages (from openai-whisper) (2.11.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/lib/python3.11/site-packages (from numba->openai-whisper) (0.42.0)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken->openai-whisper) (2026.5.9)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken->openai-whisper) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->tiktoken->openai-whisper) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.11/site-packages (from requests->tiktoken->openai-whisper) (2.7.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.11/site-packages (from torch->openai-whisper) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from torch->openai-whisper) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from torch->openai-whisper) (3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Downloading gradio-6.18.0-py3-none-any.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 13.3 MB/s  0:00:02m0:00:0100:01
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading fastapi-0.137.1-py3-none-any.whl (121 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.19.0-py3-none-any.whl (693 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 693.4/693.4 kB 8.2 MB/s  0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading brotli-1.2.0-cp311-cp311-macosx_10_9_universal2.whl (863 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.1/863.1 kB 5.3 MB/s  0:00:00
# Using cached click-8.4.1-py3-none-any.whl (116 kB)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=50f235e76c04d542c8b0859f85aa446eb72751d900ac22d3b34e12ccbd2137e5
#   Stored in directory: /Users/disha/Library/Caches/pip/wheels/32/d2/9a/801b5cc5b2a1af2e280089b71c326711a682fc1d50ea29d0ed
# Successfully built openai-whisper
# Installing collected packages: pydub, brotli, tomlkit, semantic-version, python-multipart, groovy, click, starlette, safehttpx, openai-whisper, fastapi, huggingface-hub, gradio-client, hf-gradio, gradio
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.0.9
#     Uninstalling Brotli-1.0.9:
#       Successfully uninstalled Brotli-1.0.9━━━━━━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#   Attempting uninstall: tomlkit━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#     Found existing installation: tomlkit 0.11.1━━━━━━━━━━━━━━━  1/15 [brotli]
#     Uninstalling tomlkit-0.11.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#       Successfully uninstalled tomlkit-0.11.1━━━━━━━━━━━━━━━━━  1/15 [brotli]
#   Attempting uninstall: click━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#     Found existing installation: click 8.1.8━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#     Uninstalling click-8.1.8:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#       Successfully uninstalled click-8.1.8━━━━━━━━━━━━━━━━━━━━  1/15 [brotli]
#   Attempting uninstall: huggingface-hub╸━━━━━━━━━━━━━ 10/15 [fastapi]
#     Found existing installation: huggingface_hub 0.36.2━━━━━━━ 10/15 [fastapi]
#     Uninstalling huggingface_hub-0.36.2:━━━━━━━━━━━━━ 10/15 [fastapi]
#       Successfully uninstalled huggingface_hub-0.36.2━━━━━━━━━ 10/15 [fastapi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [gradio]14/15 [gradio]face-hub]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tokenizers 0.19.1 requires huggingface-hub<1.0,>=0.16.4, but you have huggingface-hub 1.19.0 which is incompatible.
# gtts 2.5.4 requires click<8.2,>=7.1, but you have click 8.4.1 which is incompatible.
# transformers 4.41.2 requires huggingface-hub<1.0,>=0.23.0, but you have huggingface-hub 1.19.0 which is incompatible.
# streamlit 1.34.0 requires packaging<25,>=16.8, but you have packaging 26.2 which is incompatible.
# streamlit 1.34.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.6 which is incompatible.
# streamlit 1.34.0 requires rich<14,>=10.14.0, but you have rich 15.0.0 which is incompatible.
# streamlit 1.34.0 requires tenacity<9,>=8.1.0, but you have tenacity 9.1.4 which is incompatible.
# Successfully installed brotli-1.2.0 click-8.4.1 fastapi-0.137.1 gradio-6.18.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 huggingface-hub-1.19.0 openai-whisper-20250625 pydub-0.25.1 python-multipart-0.0.32 safehttpx-0.1.7 semantic-version-2.10.0 starlette-1.3.1 tomlkit-0.14.0

# %%
import gradio as gr
import whisper

print("Libraries installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import gradio as gr
# ----> 2 import whisper
#       4 print("Libraries installed successfully!")
#
# ModuleNotFoundError: No module named 'whisper'

# %%
import sys

# !{sys.executable} -m pip install openai-whisper gradio
# Out:
# Collecting openai-whisper
#   Using cached openai_whisper-20250625.tar.gz (803 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gradio in ./opt/anaconda3/lib/python3.9/site-packages (4.44.1)
# Collecting more-itertools (from openai-whisper)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numba in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper) (0.55.1)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper) (1.26.4)
# Requirement already satisfied: tiktoken in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper) (0.13.0)
# Requirement already satisfied: torch in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper) (2.2.2)
# Requirement already satisfied: tqdm in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper) (4.68.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (4.12.1)
# Requirement already satisfied: fastapi<1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.128.8)
# Requirement already satisfied: ffmpy in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.36.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.11.3)
# Requirement already satisfied: markupsafe~=2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.0.1)
# Requirement already satisfied: matplotlib~=3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (3.5.1)
# Requirement already satisfied: orjson~=3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (1.4.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (9.0.1)
# Requirement already satisfied: pydantic>=2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.2.2 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.15.16)
# Requirement already satisfied: semantic-version~=2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: typing-extensions~=4.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (4.15.0)
# Collecting urllib3~=2.0 (from gradio)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: uvicorn>=0.14.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio) (0.39.0)
# Requirement already satisfied: fsspec in ./opt/anaconda3/lib/python3.9/site-packages (from gradio-client==1.3.0->gradio) (2025.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./opt/anaconda3/lib/python3.9/site-packages (from anyio<5.0,>=3.0->gradio) (3.3)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fastapi<1.0->gradio) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./opt/anaconda3/lib/python3.9/site-packages (from fastapi<1.0->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from fastapi<1.0->gradio) (0.0.4)
# Requirement already satisfied: zipp>=3.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.23.1)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio) (2021.3)
# Requirement already satisfied: click>=8.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: certifi in ./opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in ./opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in ./opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (3.19.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (1.5.1)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (2.46.4)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./opt/anaconda3/lib/python3.9/site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in ./opt/anaconda3/lib/python3.9/site-packages (from numba->openai-whisper) (0.38.0)
# Collecting numpy (from openai-whisper)
#   Downloading numpy-1.21.6-cp39-cp39-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.9/site-packages (from numba->openai-whisper) (61.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: regex in ./opt/anaconda3/lib/python3.9/site-packages (from tiktoken->openai-whisper) (2022.3.15)
# Requirement already satisfied: sympy in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper) (1.10.1)
# Requirement already satisfied: networkx in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper) (2.7.1)
# Requirement already satisfied: mpmath>=0.19 in ./opt/anaconda3/lib/python3.9/site-packages (from sympy->torch->openai-whisper) (1.2.1)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading numpy-1.21.6-cp39-cp39-macosx_10_9_x86_64.whl (17.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 6.5 MB/s  0:00:02 eta 0:00:01
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=cf495425babf4dca97c2b31e8dfc37d4e91fa6571ecb3119fbc88cdbe0966b74
#   Stored in directory: /Users/disha/Library/Caches/pip/wheels/8a/52/46/c497a169da69d4edcfe4e66e2f597ce258c334d74d371bf8c9
# Successfully built openai-whisper
# Installing collected packages: urllib3, numpy, more-itertools, openai-whisper
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.20
#     Uninstalling urllib3-1.26.20:
#       Successfully uninstalled urllib3-1.26.20
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [numpy]
#       Successfully uninstalled numpy-1.26.4━━━━━━━━━━━━━━━━━━━ 1/4 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [openai-whisper]m [numpy]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# botocore 1.24.32 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.6.3 which is incompatible.
# chromadb 0.5.3 requires numpy<2.0.0,>=1.22.5, but you have numpy 1.21.6 which is incompatible.
# geopandas 0.14.4 requires numpy>=1.22, but you have numpy 1.21.6 which is incompatible.
# ibm-cos-sdk-core 2.11.0 requires urllib3<1.27,>=1.26.7, but you have urllib3 2.6.3 which is incompatible.
# langchain-community 0.3.31 requires numpy>=1.26.2; python_version < "3.13", but you have numpy 1.21.6 which is incompatible.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 1.21.6 which is incompatible.
# streamlit 1.34.0 requires protobuf<5,>=3.20, but you have protobuf 6.33.6 which is incompatible.
# Successfully installed more-itertools-10.8.0 numpy-1.21.6 openai-whisper-20250625 urllib3-2.6.3

# %%
import gradio as gr
import whisper

print("Libraries installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 import gradio as gr
# ----> 2 import whisper
#       4 print("Libraries installed successfully!")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/whisper/__init__.py:13, in <module>
#      11 from .audio import load_audio, log_mel_spectrogram, pad_or_trim
#      12 from .decoding import DecodingOptions, DecodingResult, decode, detect_language
# ---> 13 from .model import ModelDimensions, Whisper
#      14 from .transcribe import transcribe
#      15 from .version import __version__
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/whisper/model.py:14, in <module>
#      12 from .decoding import decode as decode_function
#      13 from .decoding import detect_language as detect_language_function
# ---> 14 from .transcribe import transcribe as transcribe_function
#      16 try:
#      17     from torch.nn.functional import scaled_dot_product_attention
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/whisper/transcribe.py:21, in <module>
#      11 from .audio import (
#      12     FRAMES_PER_SECOND,
#      13     HOP_LENGTH,
#    (...)
#      18     pad_or_trim,
#      19 )
#      20 from .decoding import DecodingOptions, DecodingResult
# ---> 21 from .timing import add_word_timestamps
#      22 from .tokenizer import LANGUAGES, TO_LANGUAGE_CODE, get_tokenizer
#      23 from .utils import (
#      24     exact_div,
#      25     format_timestamp,
#    (...)
#      31     str2bool,
#      32 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/whisper/timing.py:7, in <module>
#       4 from dataclasses import dataclass
#       5 from typing import TYPE_CHECKING, List
# ----> 7 import numba
#       8 import numpy as np
#       9 import torch
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numba/__init__.py:42, in <module>
#      38 from numba.core.decorators import (cfunc, generated_jit, jit, njit, stencil,
#      39                                    jit_module)
#      41 # Re-export vectorize decorators and the thread layer querying function
# ---> 42 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      43                             get_num_threads, set_num_threads)
#      45 # Re-export Numpy helpers
#      46 from numba.np.numpy_support import carray, farray, from_dtype
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numba/np/ufunc/__init__.py:3, in <module>
#       1 # -*- coding: utf-8 -*-
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
#       5 from numba.np.ufunc import _internal, array_exprs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numba/np/ufunc/decorators.py:3, in <module>
#       1 import inspect
# ----> 3 from numba.np.ufunc import _internal
#       4 from numba.np.ufunc.parallel import ParallelUFuncBuilder, ParallelGUFuncBuilder
#       6 from numba.core.registry import DelayedRegistry
#
# SystemError: initialization of _internal failed without raising an exception

# %%
import sys
print(sys.executable)
# Out:
# /Users/disha/opt/anaconda3/bin/python

# %%
import sys

# !{sys.executable} -m pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /private/var/folders/nd/1808h08j3sn54v03kjcsytlc0000gn/T/pip-req-build-outzuzp7
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /private/var/folders/nd/1808h08j3sn54v03kjcsytlc0000gn/T/pip-req-build-outzuzp7
#   Resolved https://github.com/openai/whisper.git to commit 04f449b8a437f1bbd3dba5c9f826aca972e7709a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper==20250625) (10.8.0)
# Requirement already satisfied: numba in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper==20250625) (0.55.1)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper==20250625) (1.21.6)
# Requirement already satisfied: tiktoken in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper==20250625) (0.13.0)
# Requirement already satisfied: torch in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper==20250625) (2.2.2)
# Requirement already satisfied: tqdm in ./opt/anaconda3/lib/python3.9/site-packages (from openai-whisper==20250625) (4.68.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in ./opt/anaconda3/lib/python3.9/site-packages (from numba->openai-whisper==20250625) (0.38.0)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.9/site-packages (from numba->openai-whisper==20250625) (61.2.0)
# Requirement already satisfied: regex in ./opt/anaconda3/lib/python3.9/site-packages (from tiktoken->openai-whisper==20250625) (2022.3.15)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.9/site-packages (from tiktoken->openai-whisper==20250625) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->tiktoken->openai-whisper==20250625) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->tiktoken->openai-whisper==20250625) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->tiktoken->openai-whisper==20250625) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->tiktoken->openai-whisper==20250625) (2021.10.8)
# Requirement already satisfied: filelock in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper==20250625) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper==20250625) (4.15.0)
# Requirement already satisfied: sympy in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper==20250625) (1.10.1)
# Requirement already satisfied: networkx in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper==20250625) (2.7.1)
# Requirement already satisfied: jinja2 in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper==20250625) (2.11.3)
# Requirement already satisfied: fsspec in ./opt/anaconda3/lib/python3.9/site-packages (from torch->openai-whisper==20250625) (2025.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch->openai-whisper==20250625) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in ./opt/anaconda3/lib/python3.9/site-packages (from sympy->torch->openai-whisper==20250625) (1.2.1)

# %%
import gradio as gr
import whisper

print("Libraries installed successfully!")
# Out:
# Libraries installed successfully!
# /Users/disha/opt/anaconda3/lib/python3.9/site-packages/numba/__init__.py:143: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.6)
#   import scipy

# %%
import whisper

model = whisper.load_model("base")

print("Whisper model loaded successfully!")
# Out:
# Whisper model loaded successfully!

# %%
import whisper

model = whisper.load_model("base")

def transcribe_audio(audio_file):
    result = model.transcribe(audio_file)
    return result["text"]

# %%
import sys

# !conda install -y -c conda-forge ffmpeg
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.7.1                  |       h463b476_0         2.0 MB  conda-forge
#     ca-certificates-2026.5.20  |       hbd8a1cb_0         127 KB  conda-forge
#     cairo-1.18.0               |       hd1e100b_0         877 KB  conda-forge
#     certifi-2026.5.20          |     pyhd8ed1ab_0         131 KB  conda-forge
#     expat-2.8.1                |       hf6b4638_1         133 KB  conda-forge
#     ffmpeg-6.1.1               | gpl_ha63e52a_101        18.8 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h82840c6_0         232 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |       hc364b38_1           4 KB  conda-forge
#     fribidi-1.0.16             |       hc919400_0          58 KB  conda-forge
#     gettext-0.25.1             |       h3dcc1bd_0         531 KB  conda-forge
#     gettext-tools-0.25.1       |       h493aca8_0         3.6 MB  conda-forge
#     gmp-6.3.0                  |       h7bae524_2         357 KB  conda-forge
#     gnutls-3.7.9               |       hd26332c_0         1.7 MB  conda-forge
#     graphite2-1.3.15           |       hf6b4638_0          80 KB  conda-forge
#     harfbuzz-8.3.0             |       h8f0ba13_0         1.2 MB  conda-forge
#     imagecodecs-2021.8.26      |  py311haa897ea_2         5.8 MB
#     lame-3.100                 |    h1a8c8d9_1003         516 KB  conda-forge
#     libarchive-3.6.2           |       h82b9b87_1         781 KB  conda-forge
#     libasprintf-0.25.1         |       h493aca8_0          51 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h493aca8_0          34 KB  conda-forge
#     libass-0.17.1              |       hf7da4fe_1         108 KB  conda-forge
#     libavif-1.0.3              |       he23855c_1          32 KB  conda-forge
#     libavif16-1.0.3            |       he23855c_1          80 KB  conda-forge
#     libcxx-22.1.8              |       h55c6f16_0         556 KB  conda-forge
#     libexpat-2.8.1             |       hf6b4638_1          68 KB  conda-forge
#     libgettextpo-0.25.1        |       h493aca8_0         179 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h493aca8_0          37 KB  conda-forge
#     libiconv-1.18              |       h23cfdf5_2         733 KB  conda-forge
#     libidn2-2.3.8              |       ha90df94_1         142 KB  conda-forge
#     libintl-0.25.1             |       h493aca8_0          89 KB  conda-forge
#     libintl-devel-0.25.1       |       h493aca8_0          39 KB  conda-forge
#     libopenvino-2023.2.0       |       h965bd2d_0         4.1 MB  conda-forge
#     libopenvino-arm-cpu-plugin-2023.2.0|       h965bd2d_0         5.4 MB  conda-forge
#     libopenvino-auto-batch-plugin-2023.2.0|       h965bd2d_0         106 KB  conda-forge
#     libopenvino-auto-plugin-2023.2.0|       h965bd2d_0         202 KB  conda-forge
#     libopenvino-hetero-plugin-2023.2.0|       h965bd2d_0         157 KB  conda-forge
#     libopenvino-ir-frontend-2023.2.0|       h965bd2d_0         164 KB  conda-forge
#     libopenvino-onnx-frontend-2023.2.0|       h965bd2d_0         1.2 MB  conda-forge
#     libopenvino-paddle-frontend-2023.2.0|       h965bd2d_0         528 KB  conda-forge
#     libopenvino-pytorch-frontend-2023.2.0|       h965bd2d_0         636 KB  conda-forge
#     libopenvino-tensorflow-frontend-2023.2.0|       h965bd2d_0         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2023.2.0|       h965bd2d_0         353 KB  conda-forge
#     libopus-1.6.1              |       h1a92334_0         301 KB  conda-forge
#     libsqlite-3.46.0           |       hfb93653_0         811 KB  conda-forge
#     libtasn1-4.21.0            |       h84a0fba_0         113 KB  conda-forge
#     libunistring-0.9.10        |       h3422bc3_0         1.5 MB  conda-forge
#     libvpx-1.13.1              |       hb765f3a_0         1.1 MB  conda-forge
#     libxml2-2.12.7             |       ha661575_1         575 KB  conda-forge
#     libxslt-1.1.39             |       h223e5b9_0         220 KB  conda-forge
#     libzlib-1.2.13             |       hfb2fe0b_6          46 KB  conda-forge
#     lxml-5.2.2                 |  py311hf9a6a72_0         1.1 MB  conda-forge
#     nettle-3.9.1               |       h40ed0f5_0         498 KB  conda-forge
#     openh264-2.4.0             |       h965bd2d_0         588 KB  conda-forge
#     openssl-3.6.3              |       hd24854e_0         3.0 MB  conda-forge
#     p11-kit-0.24.1             |       h29577a5_0         870 KB  conda-forge
#     pixman-0.46.4              |       h81086ad_1         242 KB  conda-forge
#     pugixml-1.14               |       h13dd4ca_0          90 KB  conda-forge
#     python-3.11.5              |h47c9636_0_cpython        14.0 MB  conda-forge
#     python_abi-3.11            |          8_cp311           7 KB  conda-forge
#     rav1e-0.6.6                |       h69fbcac_2         1.5 MB  conda-forge
#     scikit-image-0.20.0        |  py311h4eec4a9_1        10.0 MB  conda-forge
#     svt-av1-1.8.0              |       h463b476_0         1.3 MB  conda-forge
#     tifffile-2021.11.2         |     pyhd8ed1ab_0         139 KB  conda-forge
#     x264-1!164.3095            |       h57fd34a_2         700 KB  conda-forge
#     x265-3.5                   |       hbc6ce65_3         1.7 MB  conda-forge
#     zfp-0.5.5                  |       hcfdfaf5_8         163 KB  conda-forge
#     zlib-1.2.13                |       hfb2fe0b_6          76 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        96.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              conda-forge/osx-arm64::cairo-1.18.0-hd1e100b_0
#   expat              conda-forge/osx-arm64::expat-2.8.1-hf6b4638_1
#   ffmpeg             conda-forge/osx-arm64::ffmpeg-6.1.1-gpl_ha63e52a_101
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.14.2-h82840c6_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
#   fribidi            conda-forge/osx-arm64::fribidi-1.0.16-hc919400_0
#   gettext-tools      conda-forge/osx-arm64::gettext-tools-0.25.1-h493aca8_0
#   gnutls             conda-forge/osx-arm64::gnutls-3.7.9-hd26332c_0
#   graphite2          conda-forge/osx-arm64::graphite2-1.3.15-hf6b4638_0
#   harfbuzz           conda-forge/osx-arm64::harfbuzz-8.3.0-h8f0ba13_0
#   lame               conda-forge/osx-arm64::lame-3.100-h1a8c8d9_1003
#   libasprintf        conda-forge/osx-arm64::libasprintf-0.25.1-h493aca8_0
#   libasprintf-devel  conda-forge/osx-arm64::libasprintf-devel-0.25.1-h493aca8_0
#   libass             conda-forge/osx-arm64::libass-0.17.1-hf7da4fe_1
#   libavif16          conda-forge/osx-arm64::libavif16-1.0.3-he23855c_1
#   libexpat           conda-forge/osx-arm64::libexpat-2.8.1-hf6b4638_1
#   libgettextpo       conda-forge/osx-arm64::libgettextpo-0.25.1-h493aca8_0
#   libgettextpo-devel conda-forge/osx-arm64::libgettextpo-devel-0.25.1-h493aca8_0
#   libidn2            conda-forge/osx-arm64::libidn2-2.3.8-ha90df94_1
#   libintl            conda-forge/osx-arm64::libintl-0.25.1-h493aca8_0
#   libintl-devel      conda-forge/osx-arm64::libintl-devel-0.25.1-h493aca8_0
#   libopenvino        conda-forge/osx-arm64::libopenvino-2023.2.0-h965bd2d_0
#   libopenvino-arm-c~ conda-forge/osx-arm64::libopenvino-arm-cpu-plugin-2023.2.0-h965bd2d_0
#   libopenvino-auto-~ conda-forge/osx-arm64::libopenvino-auto-batch-plugin-2023.2.0-h965bd2d_0
#   libopenvino-auto-~ conda-forge/osx-arm64::libopenvino-auto-plugin-2023.2.0-h965bd2d_0
#   libopenvino-heter~ conda-forge/osx-arm64::libopenvino-hetero-plugin-2023.2.0-h965bd2d_0
#   libopenvino-ir-fr~ conda-forge/osx-arm64::libopenvino-ir-frontend-2023.2.0-h965bd2d_0
#   libopenvino-onnx-~ conda-forge/osx-arm64::libopenvino-onnx-frontend-2023.2.0-h965bd2d_0
#   libopenvino-paddl~ conda-forge/osx-arm64::libopenvino-paddle-frontend-2023.2.0-h965bd2d_0
#   libopenvino-pytor~ conda-forge/osx-arm64::libopenvino-pytorch-frontend-2023.2.0-h965bd2d_0
#   libopenvino-tenso~ conda-forge/osx-arm64::libopenvino-tensorflow-frontend-2023.2.0-h965bd2d_0
#   libopenvino-tenso~ conda-forge/osx-arm64::libopenvino-tensorflow-lite-frontend-2023.2.0-h965bd2d_0
#   libopus            conda-forge/osx-arm64::libopus-1.6.1-h1a92334_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.46.0-hfb93653_0
#   libtasn1           conda-forge/osx-arm64::libtasn1-4.21.0-h84a0fba_0
#   libunistring       conda-forge/osx-arm64::libunistring-0.9.10-h3422bc3_0
#   libvpx             conda-forge/osx-arm64::libvpx-1.13.1-hb765f3a_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.2.13-hfb2fe0b_6
#   nettle             conda-forge/osx-arm64::nettle-3.9.1-h40ed0f5_0
#   openh264           conda-forge/osx-arm64::openh264-2.4.0-h965bd2d_0
#   p11-kit            conda-forge/osx-arm64::p11-kit-0.24.1-h29577a5_0
#   pixman             conda-forge/osx-arm64::pixman-0.46.4-h81086ad_1
#   pugixml            conda-forge/osx-arm64::pugixml-1.14-h13dd4ca_0
#   python_abi         conda-forge/noarch::python_abi-3.11-8_cp311
#   rav1e              conda-forge/osx-arm64::rav1e-0.6.6-h69fbcac_2
#   svt-av1            conda-forge/osx-arm64::svt-av1-1.8.0-h463b476_0
#   x264               conda-forge/osx-arm64::x264-1!164.3095-h57fd34a_2
#   x265               conda-forge/osx-arm64::x265-3.5-hbc6ce65_3
#
# The following packages will be UPDATED:
#
#   aom                       pkgs/main::aom-3.6.0-h313beb8_0 --> conda-forge::aom-3.7.1-h463b476_0
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2026.5.20-hbd8a1cb_0
#   certifi            pkgs/main/osx-arm64::certifi-2024.2.2~ --> conda-forge/noarch::certifi-2026.5.20-pyhd8ed1ab_0
#   gettext              pkgs/main::gettext-0.21.0-h13f89a0_1 --> conda-forge::gettext-0.25.1-h3dcc1bd_0
#   gmp                       pkgs/main::gmp-6.2.1-hc377ac9_3 --> conda-forge::gmp-6.3.0-h7bae524_2
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-73.2-hc8870d7_0
#   libavif              pkgs/main::libavif-0.11.1-h80987f9_0 --> conda-forge::libavif-1.0.3-he23855c_1
#   libcxx                pkgs/main::libcxx-14.0.6-h848a8c0_0 --> conda-forge::libcxx-22.1.8-h55c6f16_0
#   libiconv              pkgs/main::libiconv-1.16-h1a28f6b_2 --> conda-forge::libiconv-1.18-h23cfdf5_2
#   libxml2              pkgs/main::libxml2-2.10.4-h0dcf63f_1 --> conda-forge::libxml2-2.12.7-ha661575_1
#   libxslt              pkgs/main::libxslt-1.1.37-h80987f9_1 --> conda-forge::libxslt-1.1.39-h223e5b9_0
#   lxml                pkgs/main::lxml-4.9.3-py311h50ffb84_0 --> conda-forge::lxml-5.2.2-py311hf9a6a72_0
#   openssl              pkgs/main::openssl-3.0.13-h1a28f6b_0 --> conda-forge::openssl-3.6.3-hd24854e_0
#   zlib                    pkgs/main::zlib-1.2.13-h5a0b063_0 --> conda-forge::zlib-1.2.13-hfb2fe0b_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   libarchive         pkgs/main::libarchive-3.6.2-h62fee54_2 --> conda-forge::libarchive-3.6.2-h82b9b87_1
#   python                pkgs/main::python-3.11.7-hb885b13_0 --> conda-forge::python-3.11.5-h47c9636_0_cpython
#   scikit-image       pkgs/main::scikit-image-0.22.0-py311h~ --> conda-forge::scikit-image-0.20.0-py311h4eec4a9_1
#   tifffile           pkgs/main/osx-arm64::tifffile-2023.4.~ --> conda-forge/noarch::tifffile-2021.11.2-pyhd8ed1ab_0
#   zfp                       pkgs/main::zfp-1.0.0-h313beb8_0 --> conda-forge::zfp-0.5.5-hcfdfaf5_8
#
# The following packages will be DOWNGRADED:
#
#   imagecodecs                     2023.1.23-py311h5e7c512_0 --> 2021.8.26-py311haa897ea_2
#
#
#
# Downloading and Extracting Packages:
# ffmpeg-6.1.1         | 18.8 MB   |                                       |   0%
# python-3.11.5        | 14.0 MB   |                                       |   0%
#
# scikit-image-0.20.0  | 10.0 MB   |                                       |   0%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    |                                       |   0%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    |                                       |   0%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    |                                       |   0%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    |                                       |   0%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.6.6          | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-5.2.2           | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.13.1        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 870 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | 2                                     |   1%
#
# scikit-image-0.20.0  | 10.0 MB   | ###########1                          |  30%
# python-3.11.5        | 14.0 MB   | #######6                              |  21%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ################4                     |  45%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ##6                                   |   7%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | #####3                                |  14%
# python-3.11.5        | 14.0 MB   | ##########                            |  27%
#
# scikit-image-0.20.0  | 10.0 MB   | ##############8                       |  40%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | #####################                 |  57%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | #######3                              |  20%
# python-3.11.5        | 14.0 MB   | ###########6                          |  31%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ##########5                           |  29%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ########################2             |  66%
#
# scikit-image-0.20.0  | 10.0 MB   | #################1                    |  46%
# python-3.11.5        | 14.0 MB   | #############                         |  35%
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #9                                    |   5%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ##########################9           |  73%
#
# ffmpeg-6.1.1         | 18.8 MB   | ##2                                   |   6%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ###############9                      |  43%
# python-3.11.5        | 14.0 MB   | ##############3                       |  39%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | #############################2        |  79%
#
# ffmpeg-6.1.1         | 18.8 MB   | ##9                                   |   8%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ##################3                   |  50%
# python-3.11.5        | 14.0 MB   | ###############5                      |  42%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ###############################4      |  85%
#
# scikit-image-0.20.0  | 10.0 MB   | ######################3               |  60%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ####################7                 |  56%
# ffmpeg-6.1.1         | 18.8 MB   | ###3                                  |   9%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | #################################3    |  90%
#
# scikit-image-0.20.0  | 10.0 MB   | #######################7              |  64%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ######################9               |  62%
# ffmpeg-6.1.1         | 18.8 MB   | ###7                                  |  10%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | #########################1            |  68%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ###################################1  |  95%
#
# scikit-image-0.20.0  | 10.0 MB   | #########################             |  68%
# ffmpeg-6.1.1         | 18.8 MB   | ####                                  |  11%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ###########################3          |  74%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ####################################9 | 100%
#
# scikit-image-0.20.0  | 10.0 MB   | ##########################3           |  71%
# ffmpeg-6.1.1         | 18.8 MB   | ####5                                 |  12%
#
# scikit-image-0.20.0  | 10.0 MB   | ###########################7          |  75%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ##############################        |  81%
# python-3.11.5        | 14.0 MB   | #####################1                |  57%
#
#
# imagecodecs-2021.8.2 | 5.8 MB    | ##################################### | 100%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ################################9     |  89%
#
# ffmpeg-6.1.1         | 18.8 MB   | #####                                 |  14%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | 1                                     |   0%
# python-3.11.5        | 14.0 MB   | ######################4               |  61%
#
# scikit-image-0.20.0  | 10.0 MB   | ##############################8       |  83%
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #####6                                |  15%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | #1                                    |   3%
# python-3.11.5        | 14.0 MB   | #######################5              |  64%
#
# ffmpeg-6.1.1         | 18.8 MB   | ######                                |  16%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | #9                                    |   5%
# python-3.11.5        | 14.0 MB   | ########################7             |  67%
#
#
#
# libopenvino-arm-cpu- | 5.4 MB    | ##################################### | 100%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | 3                                     |   1%
#
# ffmpeg-6.1.1         | 18.8 MB   | ######4                               |  17%
# python-3.11.5        | 14.0 MB   | #########################8            |  70%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ###1                                  |   8%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | ###3                                  |   9%
#
# scikit-image-0.20.0  | 10.0 MB   | ###################################1  |  95%
# python-3.11.5        | 14.0 MB   | ##########################9           |  73%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ######7                               |  18%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | ######6                               |  18%
#
# scikit-image-0.20.0  | 10.0 MB   | ####################################4 |  99%
# python-3.11.5        | 14.0 MB   | ############################          |  76%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #######1                              |  19%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | #########8                            |  27%
# python-3.11.5        | 14.0 MB   | #############################1        |  79%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #######4                              |  20%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | #############7                        |  37%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | 1                                     |   1%
# python-3.11.5        | 14.0 MB   | ##############################4       |  82%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #######8                              |  21%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | #####2                                |  14%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | #################6                    |  48%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ###########8                          |  32%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | ########4                             |  23%
# python-3.11.5        | 14.0 MB   | ###############################5      |  85%
#
# ffmpeg-6.1.1         | 18.8 MB   | ########1                             |  22%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | ####################7                 |  56%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | #############8                        |  37%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | #############6                        |  37%
# python-3.11.5        | 14.0 MB   | ################################8     |  89%
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ########5                             |  23%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ################                      |  43%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | ##################3                   |  50%
# python-3.11.5        | 14.0 MB   | #################################9    |  92%
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ########8                             |  24%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ##################                    |  49%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | #######################               |  62%
# python-3.11.5        | 14.0 MB   | ###################################   |  95%
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #########2                            |  25%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ####################                  |  54%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | ###########################3          |  74%
# python-3.11.5        | 14.0 MB   | ####################################2 |  98%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | ##################################7   |  94%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #########6                            |  26%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | ###############################4      |  85%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | 3                                     |   1%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    | 3                                     |   1%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    | #########2                            |  25%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | ########5                             |  23%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##########5                           |  29%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    | #######2                              |  20%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
# openssl-3.6.3        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    | ###############3                      |  41%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | ###############8                      |  43%
#
#
#
#
#
# gettext-tools-0.25.1 | 3.6 MB    | ##################################### | 100%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    | ################5                     |  45%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    | ########################8             |  67%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | #######################4              |  63%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    | ##########################5           |  72%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    | #################################5    |  91%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | ##############################        |  81%
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    | ##################################4   |  93%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | ####################################7 |  99%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ####################################6 |  99%
#
#
#
#
#
#
#
# aom-3.7.1            | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##############2                       |  38%
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ############7                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #############1                        |  35%
#
#
#
#
#
#
#
#
# x265-3.5             | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##############2                       |  39%
#
#
#
#
# libopenvino-2023.2.0 | 4.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | 4                                     |   1%
# python-3.11.5        | 14.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.2 MB    | ##########1                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.8.0        | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.6.6          | 1.5 MB    | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.2 MB    | ##################5                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.6.6          | 1.5 MB    | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.6.6          | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.13.1        | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 870 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.13.1        | 1.1 MB    | #############8                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 870 KB    | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.13.1        | 1.1 MB    | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-5.2.2           | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 870 KB    | ###########################9          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.13.1        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-5.2.2           | 1.1 MB    | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ###################2                  |  52% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-5.2.2           | 1.1 MB    | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ###################8                  |  54% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-5.2.2           | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-5.2.2           | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.1         | 18.8 MB   | ##################################### | 100% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import shutil

print(shutil.which("ffmpeg"))
# Out:
# /opt/anaconda3/bin/ffmpeg

# %%
import whisper

model = whisper.load_model("base")

print("Whisper is ready!")
# Out:
# /Users/disha/opt/anaconda3/lib/python3.9/site-packages/numba/__init__.py:143: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.6)
#   import scipy
# Whisper is ready!

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /Users/disha
# ['apple', 'regressionbasic.ipynb', 'basiccode.ipynb', 'Lecture4CCvsQM2.py', '.Rhistory', 'housing.csv', '.config', 'Music', 'simplelinearregression.ipynb', 'simplelinearreg(1).ipynb', '.zprofile.pysave', 'frequencyandistribution.ipynb', '.condarc', 'Nat Gas (JPMC).ipynb', 'multiplelinearreg(2).ipynb', '.copilot', 'work documents .savedSearch', '2.02.+Binary+predictors.csv', 'train test split.ipynb', 'Untitled1.ipynb', 'Simpletradingstratergy.ipynb', '.DS_Store', 'associationbttworvariables.ipynb', '.vscode-shared', 'movingaverage.ipynb', '.CFUserTextEncoding', 'Emissions_motorsports.csv', 'basiccodepractice(4).ipynb', 'Lecture4CCvsQM3.py', '.xonshrc', 'story.mp3', 'facebook.csv', 'west side.mp3', 'Untitled3.ipynb', 'applereport.pdf', 'Untitled.ipynb', 'populationandsample.ipynb', '.zshrc', '.streamlit', '.local', 'logistic regression(1).ipynb', 'Pictures', 'apple.csv', 'outcomesandvariables.ipynb', '1.03.+Dummies.csv', '.atom', '.zprofile', 'modelsofstockreturn.ipynb', '1.01. Simple linear regression.csv', 'Nat Gas 2(JPMC).ipynb', 'logisticregst.ipynb', 'DataFrame.ipynb', 'food_recommendation_dataset.csv', 'python practice.ipynb', '.zsh_history', 'Untitled2.ipynb', '.ipython', '1.04.+Real-life+example.csv', 'Desktop', 'Library', 'basiccodepractice(2).ipynb', 'hypothesistesting.ipynb', '.matplotlib', 'iCloud Drive (Archive)', 'ConfidenceInterval.ipynb', 'linear regressionwithdatapre.ipynb', 'seaborn-data', 'Market Research', '.cups', 'flagged', 'Lecture4(completed).py', 'PycharmProjects', 'Public', '3D Yeild curve & Cartogram (HW).ipynb', '.idlerc', '2.01.+Admittance.csv', 'variationofsample.ipynb', 'exercises', '.tcshrc', '.cisco', '.RData', 'simplelinearreg(2).ipynb', 'YT Project', 'Loan Data 3 (JPMC).ipynb', 'Gradio.ipynb', '.anaconda', '1.02.+Multiple+linear+regression.csv', 'Nat_Gas.csv', 'Movies', 'Applications', 'microsoft.csv', 'Task 3 and 4_Loan_Data.csv', 'RAG.ipynb', '.Rapp.history', 'multiplelinearreg(1).ipynb', 'opt', '.Trash', 'Emissions_motorsports.xlsx', 'chroma_db', '.ipynb_checkpoints', 'basiccodepractice(1).ipynb', '.jupyter', 'Lecture4CCvsQM4.py', 'Documents', 'LangChain.ipynb', 'dummies.ipynb', '.vscode', '.bash_profile', 'standardisation.ipynb', 'Downloads', '.python_history', 'FEWP lecture 3 .ipynb', '.empty', '.continuum', '.cache', 'Lecture4CCvsQM1.py', 'FEWP lecture 3 -Copy1.ipynb', 'food_chroma_db', '.zsh_sessions', 'basiccodepractice(3).ipynb', '.conda', 'work documents.savedSearch', 'gdp_change_f1_races.png']

# %%
audio_path = "west side.mp3"

result = model.transcribe(audio_path)

print(result["text"])
# Out:
# /Users/disha/opt/anaconda3/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  I Don't want to think so much. I just want to feel You know that ain't no Let me keep it real Just let me be in your life like that in your life like that I'll bring the light back I'll bring the light back. I'm gonna make you one more I'm gonna be a new favorite Tell them you close in the door I am the only for sure Horder the shirt and be no holder There's more love if you follow emotions show up If you don't roll up, be me on the right side for me Horder the shirt and be no holder there's more love if you follow emotions show up Now if you don't roll up, be me on the one and if it ain't just touch It's better every time we chill you ain't gotta bring those stuff We gonna be neat right here Just let me be in your life like that be your wife like that I'll bring the light back. I'll bring the light back I'm gonna make you one more. I'm gonna be a new favorite Tell them you close in the door. I am the only for sure I'm gonna be a new favorite Horder the shirt and be no holder there's more love if you follow emotions show up Now if you don't roll up, be me on the right side for me Horder the shirt and be no holder there's more love if you follow emotions show up Now if you don't roll up, be me on the right side for me
